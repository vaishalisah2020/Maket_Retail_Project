# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
orders = pd.read_excel("Retail_dataset.xlsx", sheet_name="orders")
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 2  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 3  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
# 4  ad21c59c0840e6cb83a9ceb5573f8159  72632f0f9dd73dfee390c9b22eb56dd6
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_timestamp order_estimated_delivery_date
# 0       2017-10-10 21:25:13                    2017-10-18
# 1       2018-08-07 15:27:45                    2018-08-13
# ...

# %%
orders.order_id.duplicated().sum()
# Out:
# 0

# %%
orders.customer_id.value_counts().sort_values(ascending=False).head()
# Out:
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# 6469f99c1f9dfae7733b25662e7f1782     7
# ca77025e7201e3b30c44b472ff346268     7
# Name: customer_id, dtype: int64

# %%
bool_series=pd.isnull(orders['order_delivered_timestamp'])

# %%
orders[bool_series]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  36edbb3fb164b1f16485364b6fb04c73
# 44     ee64d42b8cf066f35eac1cf57de1aa85  08fb46d35bb3ab4037202c23592d1259
# 103    0760a852e4e9d89eb77bf631eaaf1c84  c7f8d7b1fffc946d7069574f74c39f4e
# 128    15bed8e2fec7fdbadb186b57c46c92f2  9f269af9c49244f6ba4a46985a3cfc2e
# 154    6942b8da583c2f9957e990d028607019  528b011eb7fab3d59c336cc7248eed3a
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  e90598185d2427a35e32ef241a5c04aa
# 99313  e9e64a17afa9653aacf2616d94c005b8  965191786b70912f793e4a777fd623cd
# 99347  a89abace0dcc01eeb267a9660b5ac126  d05c44a138277ad325d915c6b7ccbcdf
# 99348  a69ba794cc7deb415c3e15a0a3877e69  e72a90a2b29fe1a8795b284aaaa3246f
# 99415  5fabc81b6322c8443648e1b21a6fef21  393d95c05b04db26ac084374094b3a52
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
delivered_orders = orders[ orders.order_status=='delivered' ]
delivered_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 2  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 3  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
# 4  ad21c59c0840e6cb83a9ceb5573f8159  72632f0f9dd73dfee390c9b22eb56dd6
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_timestamp order_estimated_delivery_date
# 0       2017-10-10 21:25:13                    2017-10-18
# 1       2018-08-07 15:27:45                    2018-08-13
# ...

# %%
delivered_orders.shape
# Out:
# (96478, 7)

# %%
delivered_orders.isna().sum()
# Out:
# order_id                          0
# customer_id                       0
# order_status                      0
# order_purchase_timestamp          0
# order_approved_at                14
# order_delivered_timestamp         8
# order_estimated_delivery_date     0
# dtype: int64

# %%
series=pd.isnull(delivered_orders['order_approved_at'])
series2=pd.isnull(delivered_orders['order_delivered_timestamp'])

# %%
delivered_orders[series]
# Out:
#                                order_id                       customer_id  \
# 5323   e04abd8149ef81b95221e88f6ed9ab6a  8a9a08c7ca8900a200d83cf838a07e0b
# 16567  8a9adc69528e1001fc68dd0aaebbb54a  91efb7fcabc17925099dced52435837f
# 19031  7013bcfc1c97fe719a7b5e05e61c12db  e1f01a1bd6485e58ad3c769a5427d8a8
# 22663  5cf925b116421afa85ee25e99b4c34fb  7e1a5ca61b572d76b64b6688b9f96473
# 23156  12a95a3c06dbaec84bcfb0e2da5d228a  c8822fce1d0bfa7ddf0da24fff947172
# 26800  c1d4211b3dae76144deccd6c74144a88  6ff8b0d7b35d5c945633b8d60165691b
# 38290  d69e5d356402adc8cf17e08b5033acfb  2e0a2166aa23da2472c6a60c4af6f7a6
# 39334  d77031d6a3c8a52f019764e68f211c69  c4c0011e639bdbcf26059ddc38bd3c18
# 48401  7002a78c79c519ac54022d4f8a65e6e8  d49f3dae6bad25d05160fc17aca5942d
# 61743  2eecb0d85f281280f79fa00f9cec1a95  5a4fa4919cbf2b049e72be460a380e5b
# 63052  51eb2eebd5d76a24625b31c33dd41449  79af1bbf230a2630487975aa5d7d6220
# 67697  88083e8f64d95b932164187484d90212  bc1896dc77f49e6dec880445a9b443a3
# ...

# %%
delivered_orders[series2]
# Out:
#                                order_id                       customer_id  \
# 3002   2d1e2d5bf4dc7227b3bfebb81328c15f  13467e882eb3a701826435ee4424f2bd
# 20618  f5dd62b788049ad9fc0526e3ad11a097  2f17c5b324ad603491521b279a9ff4de
# 43834  2ebdfc4f15f23b91474edf87475f108e  1bd06a0c0df8b23dacfd3725d2dc0bb9
# 79263  e69f75a717d64fc5ecdfae42b2e8e086  3bc508d482a402715be4d5cf4020cc81
# 82868  0d3268bad9b086af767785e3f0fc0133  ebf7e0d43a78c81991a4c59c145c75db
# 92643  2d858f451373b04fb5c984a1cc2defaf  d77cf4be2654aa70ef150f8bfec076a6
# 97647  ab7c89dc1bf4a1ead9d6ec1ec8968a84  cce5e8188bf42ffb3bb5b18ff58f5965
# 98038  20edc82cf5400ce95e1afacc25798b31  175378436e2978be55b8f4316bce4811
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 3002     delivered      2017-11-28 17:44:07 2017-11-28 17:56:40
# 20618    delivered      2018-06-20 06:58:43 2018-06-20 07:19:05
# 43834    delivered      2018-07-01 17:05:11 2018-07-01 17:15:12
# ...

# %%
delivered_orders.order_approved_at.fillna(delivered_orders.order_purchase_timestamp, inplace=True)

delivered_orders.order_delivered_timestamp.fillna(delivered_orders.order_estimated_delivery_date, inplace=True)

# %%
delivered_orders.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_timestamp        0
# order_estimated_delivery_date    0
# dtype: int64

# %%
order_items = pd.read_excel("Retail_dataset.xlsx", sheet_name="order_items")
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    shipping_charges
# 0             13.29
# 1             19.93
# 2             17.87
# 3             12.79
# 4             18.14

# %%
order_items.isna().sum()
# Out:
# order_id            0
# order_item_id       0
# product_id          0
# seller_id           0
# price               0
# shipping_charges    0
# dtype: int64

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          112650 non-null  object
#  1   order_item_id     112650 non-null  int64
#  2   product_id        112650 non-null  object
#  3   seller_id         112650 non-null  object
#  4   price             112650 non-null  float64
#  5   shipping_charges  112650 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 5.2+ MB

# %%
customers = pd.read_excel("Retail_dataset.xlsx", sheet_name="customers")
customers.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  861eff4711a542e4b93843c6dd7febb0                     14409
# 1  290c77bc529b7ac935b93aa66c333dc3                      9790
# 2  060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3  259dac757896d24d7702b9acbbff3f3c                      8775
# 4  345ecd01c38d18a9036ed96c73b8d066                     13056
#
#            customer_city customer_state
# 0                 franca             SP
# 1  sao bernardo do campo             SP
# 2              sao paulo             SP
# 3        mogi das cruzes             SP
# 4               campinas             SP

# %%
customers.isna().sum()
# Out:
# customer_id                 0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers.customer_id.duplicated().sum()
# Out:
# 3345

# %%
customers[customers.customer_id.duplicated()]
# Out:
#                             customer_id  customer_zip_code_prefix  \
# 679    b6c083700ca8c135ba9f0f132930d4e8                      8686
# 1463   a40096fc0a3862e9e12bc55b5f8e6ab2                     20561
# 1607   b8b3c435a58aebd788a477bed8342910                     95585
# 2811   66980c3775537536f77b434d74e520f5                     30290
# 3198   788313d21c3507fe890921f6e17aa679                     11070
# ...                                 ...                       ...
# 99324  8bab3162259edfaadd1ea2e1fe7f58dc                     31565
# 99327  12ab9334b1240d6d037f2b0102a49571                     38050
# 99336  0ee57f62666561b72f2ceacad0230cbf                      9530
# 99353  0ceb502fc33a2ad327b08288c5310e2e                     29134
# 99406  5cbfdb85ec130898108b32c50d619c39                     74980
#
#               customer_city customer_state
# 679                  suzano             SP
# 1463         rio de janeiro             RJ
# ...

# %%
customers[customers.customer_id.duplicated()].shape
# Out:
# (3345, 4)

# %%
customers.shape
# Out:
# (99441, 4)

# %%
customers.drop_duplicates(subset='customer_id', keep='first',inplace=True)

# %%
customers.shape
# Out:
# (96096, 4)

# %%
payments = pd.read_excel("Retail_dataset.xlsx", sheet_name="payments")
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
products = pd.read_excel("Retail_dataset.xlsx", sheet_name="products")
products.head()
# Out:
#                          product_id product_category_name  product_weight_g  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumery             225.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f                   art            1000.0
# 2  96bd76ec8810374ed1b65e291975717f        sports_leisure             154.0
# 3  cef67bcfe19066a932b7673e239eb23d                  baby             371.0
# 4  9dc1a7de274444849c219cff195d0b71            housewares             625.0
#
#    product_length_cm  product_height_cm  product_width_cm
# 0               16.0               10.0              14.0
# 1               30.0               18.0              20.0
# 2               18.0                9.0              15.0
# 3               26.0                4.0              26.0
# 4               20.0               17.0              13.0

# %%
products.isna().sum()
# Out:
# product_id                 0
# product_category_name    170
# product_weight_g           2
# product_length_cm          2
# product_height_cm          2
# product_width_cm           2
# dtype: int64

# %%
products.product_category_name.value_counts()
# Out:
# toys                                 24725
# bed_bath_table                         789
# sports_leisure                         721
# furniture_decor                        687
# health_beauty                          648
#                                      ...
# fashion_childrens_clothes                1
# diapers_and_hygiene                      1
# home_comfort_2                           1
# security_and_services                    1
# furniture_mattress_and_upholstery        1
# Name: product_category_name, Length: 70, dtype: int64

# %%
products.product_category_name.mode()
# Out:
# 0    toys
# Name: product_category_name, dtype: object

# %%
products.product_category_name.mode()[0]
# Out:
# 'toys'

# %%
products.product_category_name.fillna(products.product_category_name.mode()[0],inplace=True)

# %%
products.isna().sum()
# Out:
# product_id               0
# product_category_name    0
# product_weight_g         2
# product_length_cm        2
# product_height_cm        2
# product_width_cm         2
# dtype: int64

# %%
products.describe()
# Out:
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
products.product_weight_g.fillna(products.product_weight_g.median(), inplace=True)
products.product_length_cm.fillna(products.product_length_cm.median(), inplace=True)
products.product_height_cm.fillna(products.product_height_cm.median(), inplace=True)
products.product_width_cm.fillna(products.product_width_cm.median(), inplace=True)

# %%
products.isna().sum()
# Out:
# product_id               0
# product_category_name    0
# product_weight_g         0
# product_length_cm        0
# product_height_cm        0
# product_width_cm         0
# dtype: int64

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    shipping_charges
# 0             13.29
# 1             19.93
# 2             17.87
# 3             12.79
# 4             18.14

# %%
order_items.shape
# Out:
# (112650, 6)

# %%
products.shape
# Out:
# (32951, 6)

# %%
order_pro_com=pd.concat([order_items,products],axis=1)

# %%
order_pro_com.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    shipping_charges                        product_id product_category_name  \
# 0             13.29  1e9e8ef04dbcff4541ed26657ea517e5             perfumery
# ...

# %%
products.head()
# Out:
#                          product_id product_category_name  product_weight_g  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumery             225.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f                   art            1000.0
# 2  96bd76ec8810374ed1b65e291975717f        sports_leisure             154.0
# 3  cef67bcfe19066a932b7673e239eb23d                  baby             371.0
# 4  9dc1a7de274444849c219cff195d0b71            housewares             625.0
#
#    product_length_cm  product_height_cm  product_width_cm
# 0               16.0               10.0              14.0
# 1               30.0               18.0              20.0
# 2               18.0                9.0              15.0
# 3               26.0                4.0              26.0
# 4               20.0               17.0              13.0

# %%
order_pro_com.shape
# Out:
# (112650, 12)

# %%
order_pro_com.drop_duplicates(keep='first',inplace=True)

# %%
order_pro_com.shape
# Out:
# (112650, 12)

# %%
order_pro_com.drop(['order_item_id', 'product_id', 'seller_id', 'price','shipping_charges', 'product_id','product_weight_g', 'product_length_cm', 'product_height_cm',
       'product_width_cm'],axis=1)
# Out:
#                                 order_id product_category_name
# 0       00010242fe8c5a6d1ba2dd792cb16214             perfumery
# 1       00018f77f2f0320c557190d7a144bdd3                   art
# 2       000229ec398224ef6ca0657da4fc703e        sports_leisure
# 3       00024acbcdf0a6daa1e931b038114c75                  baby
# 4       00042b26cf59d7ce69dfabb4e55b4fd9            housewares
# ...                                  ...                   ...
# 112645  fffc94f6ce00a00581880bf54a75a037                   NaN
# 112646  fffcd46ef2263f404302a634eb57f7eb                   NaN
# 112647  fffce4705a9662cd70adb13d4a31832d                   NaN
# 112648  fffe18544ffabc95dfada21779c9644f                   NaN
# 112649  fffe41c64501cc87c801fd61db3f6244                   NaN
#
# [112650 rows x 2 columns]

# %%
order_pro_com
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %%
delivered_orders.shape
# Out:
# (96478, 7)

# %%
order_items.shape
# Out:
# (112650, 6)

# %%
products.shape
# Out:
# (32951, 6)

# %%
order_pro=pd.concat([order_items,products],join='inner',axis=1)

# %%
order_pro.shape
# Out:
# (32951, 12)
